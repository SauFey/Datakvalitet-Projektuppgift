# %% [markdown]
# ### Inför redovisning:
#
# 1. Visa uppladdning av CSV-filer
#     Raw
#     Clean
#     Bad
#
# 2. Visa etl-pipeline och kör den (Validering)
#     Visar att min datarensning och laddning till databasen fungerar
#
#     python etl-pipeline.py
#
# 3. Kör Alembic      (Versionshantering för databasen)
#     alembic upgrade head
#
# 4. Testa transaktioner med Pytest (Söker efter test_ och kör asserts bl.a)
#     pytest
#
# 5. Kontrollera databasen

# %% [markdown]
# ### 1. Läs in CSV-filerna
#
#     1.     Läs in filerna i pandas                                                                  KLAR
#     2.     Skapa en fil som utgångspunkt för arbetet - etl-pipeline.ipynb                           KLAR
#
# ### 2. Transformera datan - Tvätta och validera
#
#     1. Kör kontroller på saknade värden,                                                            KLAR
#         felaktiga datum,                                                                            KLAR
#         IBAN,                                                                                       KLAR
#         negativa transaktioner,                                                                     KLAR
#         andra mönster.                                                                              KLAR
#     2. Sparar felaktiga rader i data/bad                                                            KLAR
#     3. Skapar rena CSV-filer i data/clean                                                           KLAR
#
# ### 3. Ladda in ren data i databasen
#
#     1. Skapa en fungerande etl-pipeline som laddar upp ren data i data.db. >> etl-pipeline.py       KLAR
#
# ### 4. Migrera och versionera databasen
#
#     1. Skapa en revision för att visa hur databasen kan versionhanteras
#         alembic upgrade head
#
# ### 5. Testning och transaktioner
#     1. Skapa transactions.py och test_transactions.py för testning                                  KLAR
#
#
#
# #### + ETL-flöde klart
# #### + Alembic är kopplat
# #### + Modeller finns (models.py och transactions.py)
# #### + Testfil finns att köra med Pytest
# #### +

# %%
import pandas as pd

from sqlalchemy import create_engine

engine = create_engine("sqlite:///bank.db")

df_customers = pd.read_sql("SELECT * FROM customers_accounts_clean LIMIT 5;", engine)
df_transactions = pd.read_sql("SELECT * FROM transactions_clean LIMIT 5;", engine)

print(df_customers)
print(df_transactions)
# Out:
#              Customer                        Address              Phone  \
# 0       Sofie Ibrahim      Ängsvägen 03, 14010 Gävle      061-608 60 88
# 1       Sofie Ibrahim      Ängsvägen 03, 14010 Gävle      061-608 60 88
# 2       Mona Lundgren  Kyrkvägen 084, 49722 Göteborg  +46 (0)396 101 64
# 3       Mona Lundgren  Kyrkvägen 084, 49722 Göteborg  +46 (0)396 101 64
# 4  Tuulikki Blomqvist    Kvarnvägen 654, 94181 Borås  +46 (0)918 939 10
#
#   Personnummer               BankAccount
# 0  400118-5901  SE8902EPWK73250364544965
# 1  400118-5901  SE8902IDSK51225196610969
# 2  391117-9285  SE8902OGIV86383792142837
# 3  391117-9285  SE8902QZEZ52320024971424
# 4  981215-7254  SE8902DWZI85436013187521
#                          transaction_id            timestamp    amount  \
# 0  62cacc89-95ca-41c0-a06f-d12950c85a37  2025-01-08 03:17:00   1174.47
# 1  d1ae6818-9d0f-4e14-bc56-0165e8123ff0  2025-01-02 19:34:00  19068.02
# 2  aa707bbc-7171-4a8f-bdd1-5a18943708d5  2025-01-12 20:08:00   7557.86
# 3  40adfe97-ed7c-483e-bd50-cdec4726fc80  2025-02-08 06:24:00  14108.32
# 4  92755c2b-332c-4f8d-960d-82f0399b4ea4  2025-02-03 09:56:00   5271.49
#
#   currency            sender_account          receiver_account sender_country  \
# 0      SEK  SE8902ZCTK81497780781136  SE8902GGWE97497502378359         Sweden
# 1      SEK  SE8902DGXX88147139459340  SE8902PLBL16144667744762         Sweden
# 2      SEK  SE8902VMWP60739361675669  SE8902JTIU30473679174736         Sweden
# 3      SEK  SE8902GHSB29020078073922  SE8902MQTA07583386361028         Sweden
# 4      SEK  SE8902PVNM34258841032637  SE8902OFTJ79383582820961         Sweden
#
#   sender_municipality receiver_country receiver_municipality transaction_type  \
# 0          Södertälje           Sweden             Stockholm         outgoing
# 1           Uddevalla           Sweden             Karlskoga         incoming
# 2               Gävle           Sweden              Nyköping         outgoing
# 3          Trelleborg           Sweden                 Gävle         outgoing
# 4            Borlänge           Sweden               Lidingö         incoming
#
#                        notes
# 0                 Tax refund
# 1             Salary payment
# 2           Subscription fee
# 3  Payment for invoice #1934
# 4              Rent transfer
